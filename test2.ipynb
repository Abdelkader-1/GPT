# %%
driver = 'ODBC Driver 18 for SQL Server'
import streamlit as st
server = 'anmx3c2yurjethctgyba6xtuaq-vkvbn7t4322edeguc3ufhjtjeu.datawarehouse.pbidedicated.windows.net'
database = 'likeCard'
user = 'a.talaat%40likecard.com'
password = 'Abdo_12345'
conn = st.experimental_connection(
    name='likeCard',
    type='sql',
    host=server,
    database=database,
    username=user,
    password=password,
    dialect='mssql'
    ,driver=driver
)

# Query data from the database
query = 'SELECT * FROM dim_products'
pet_owners = conn.execute(query).fetchall()

# Display the data using Streamlit
st.dataframe(pet_owners)
# Out:
# ---------------------------------------------------------------------------
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File c:\Users\AbdelKaderTalaat\anaconda3\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:264, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     263 try:
# --> 264     cached_result = cache.read_result(value_key)
#     265     return self._handle_cache_hit(cached_result)
#
# File c:\Users\AbdelKaderTalaat\anaconda3\Lib\site-packages\streamlit\runtime\caching\cache_resource_api.py:500, in ResourceCache.read_result(self, key)
#     498 if key not in self._mem_cache:
#     499     # key does not exist in cache.
# --> 500     raise CacheKeyNotFoundError()
#     502 multi_results: MultiCacheResults = self._mem_cache[key]
#
# CacheKeyNotFoundError:
#
# During handling of the above exception, another exception occurred:
#
# CacheKeyNotFoundError                     Traceback (most recent call last)
# ...
